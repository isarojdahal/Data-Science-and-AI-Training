# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# Create a simple Series (e.g., Price in Lakhs)
prices = pd.Series([10, 12, 15, 14, 13, 50], name='Price')

# Scikit-learn expects a 2D array, so we reshape (-1, 1)
# converts 1D data to 2D data.
# -1 = figure out automatically (give me as many rows as needed to fit the data)
# 1 = tells NumPy to create exactly 1 column.
data_2d = prices.values.reshape(-1, 1)

print(data_2d)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
#       4 # Create a simple Series (e.g., Price in Lakhs)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Initialize Scalers
std_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()
robust_scaler = RobustScaler()


normalized_values = minmax_scaler.fit_transform(data_2d);
print(normalized_values)
# Out:
#    Original  Standardized (Z-Score)  Normalized (0-1)  Robust (IQR)
# 0        10                   -0.65              0.00          -1.4
# 1        12                   -0.50              0.05          -0.6
# 2        15                   -0.29              0.12           0.6
# 3        14                   -0.36              0.10           0.2
# 4        13                   -0.43              0.08          -0.2
# 5        50                    2.22              1.00          14.6
