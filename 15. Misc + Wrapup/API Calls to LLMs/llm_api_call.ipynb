# %%
#ui add google-genai

from google import genai


client = genai.Client(api_key="")

prompt = f"""
    
    Give a poem by RabindraNath Togre
    """
    
try:
    response = client.models.generate_content(
            model='gemini-3-flash-preview',
            contents=prompt
        )
    print(response.text)
except Exception as e:
    print(f"Error calling Gemini: {e}")
# Out:
# Rabindranath Tagore was a legendary poet, philosopher, and the first non-European to win the Nobel Prize in Literature.
#
# His most famous poem, often titled **"Where the Mind is Without Fear"** (originally published in his collection *Gitanjali*), is a powerful prayer for freedom and awakening.
#
# ***
#
# ### Where the Mind is Without Fear
# **By Rabindranath Tagore**
#
# Where the mind is without fear and the head is held high;
# Where knowledge is free;
# Where the world has not been broken up into fragments
# By narrow domestic walls;
# Where words come out from the depth of truth;
# Where tireless striving stretches its arms towards perfection;
# Where the clear stream of reason has not lost its way
# Into the dreary desert sand of dead habit;
# Where the mind is led forward by thee
# Into ever-widening thought and action;
# Into that heaven of freedom, my Father, let my country awake.
#
# ***
#
# ### A Brief Note on the Poem:
# Tagore wrote this poem while India was still under British rule. It is not just a plea for political independence, but a vision for a "spiritual freedom" where people are guided by reason, truth, and logic rather than superstition and prejudice.
